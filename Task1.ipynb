# %% [markdown]
# # Task 1

# %% [markdown]
# ## Import Necessary Libraries

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set the seaborn style
sns.set(style="whitegrid")

# %% [markdown]
# ## Load the Dataset

# %%
df = pd.read_csv("worldpopulationdata.csv")

# %%
df
# Out:
#                                    Series Name        Series Code  \
# 0                            Population, total        SP.POP.TOTL
# 1                            Population, total        SP.POP.TOTL
# 2                            Population, total        SP.POP.TOTL
# 3                            Population, total        SP.POP.TOTL
# 4                            Population, total        SP.POP.TOTL
# ...                                        ...                ...
# 1080  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1081  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1082  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1083  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1084  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
#
#                Country Name Country Code          2022          2021  \
# 0               Afghanistan          AFG  4.112877e+07  4.009946e+07
# ...

# %% [markdown]
# ## Checking the top 5 rows of data

# %%
print(df.head())
# Out:
#          Series Name  Series Code    Country Name Country Code        2022  \
# 0  Population, total  SP.POP.TOTL     Afghanistan          AFG  41128771.0
# 1  Population, total  SP.POP.TOTL         Albania          ALB   2775634.0
# 2  Population, total  SP.POP.TOTL         Algeria          DZA  44903225.0
# 3  Population, total  SP.POP.TOTL  American Samoa          ASM     44273.0
# 4  Population, total  SP.POP.TOTL         Andorra          AND     79824.0
#
#          2021        2020        2019        2018        2017  ...  \
# 0  40099462.0  38972230.0  37769499.0  36686784.0  35643418.0  ...
# 1   2811666.0   2837849.0   2854191.0   2866376.0   2873457.0  ...
# 2  44177969.0  43451666.0  42705368.0  41927007.0  41136546.0  ...
# 3     45035.0     46189.0     47321.0     48424.0     49463.0  ...
# 4     79034.0     77700.0     76343.0     75013.0     73837.0  ...
#
#          2010        2009        2008        2007        2006        2005  \
# ...

# %% [markdown]
# ## Checking data from the bottom

# %%
print(df.tail())
# Out:
#                                    Series Name        Series Code  \
# 1080  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1081  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1082  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1083  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1084  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
#
#                Country Name Country Code       2022       2021       2020  \
# 1080  Virgin Islands (U.S.)          VIR  46.613382  46.764444  46.914637
# 1081     West Bank and Gaza          PSE  49.893678  49.877839  49.858957
# 1082            Yemen, Rep.          YEM  50.519031  50.538516  50.554317
# 1083                 Zambia          ZMB  49.344602  49.344951  49.338301
# 1084               Zimbabwe          ZWE  47.214139  47.167153  47.130679
#
#            2019       2018       2017  ...       2010       2009       2008  \
# ...

# %% [markdown]
# ## Checking the columns of the dataset

# %%
print(df.columns)
# Out:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code', '2022',
#        '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013',
#        '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004',
#        '2003', '2002', '2001'],
#       dtype='object')

# %% [markdown]
# ## Some information about the dataset

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Series Name   1085 non-null   object
#  1   Series Code   1085 non-null   object
#  2   Country Name  1085 non-null   object
#  3   Country Code  1085 non-null   object
#  4   2022          1085 non-null   float64
#  5   2021          1085 non-null   float64
#  6   2020          1085 non-null   float64
#  7   2019          1085 non-null   float64
#  8   2018          1085 non-null   float64
#  9   2017          1085 non-null   float64
#  10  2016          1085 non-null   float64
#  11  2015          1085 non-null   float64
#  12  2014          1085 non-null   float64
#  13  2013          1085 non-null   float64
#  14  2012          1085 non-null   float64
#  15  2011          1085 non-null   float64
#  16  2010          1085 non-null   float64
# ...

# %% [markdown]
# ## Checking for duplicate values

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ##  Checking for missing values

# %%
print(df.isnull().sum())
# Out:
# Series Name     0
# Series Code     0
# Country Name    0
# Country Code    0
# 2022            0
# 2021            0
# 2020            0
# 2019            0
# 2018            0
# 2017            0
# 2016            0
# 2015            0
# 2014            0
# 2013            0
# 2012            0
# 2011            0
# 2010            0
# 2009            0
# 2008            0
# 2007            0
# 2006            0
# 2005            0
# 2004            0
# 2003            0
# 2002            0
# 2001            0
# dtype: int64

# %% [markdown]
# ## Checking unique values for each column

# %%
for col in df.columns:
    print(f'Unique values in {col}: {df[col].nunique()}')
# Out:
# Unique values in Series Name: 5
# Unique values in Series Code: 5
# Unique values in Country Name: 217
# Unique values in Country Code: 217
# Unique values in 2022: 1085
# Unique values in 2021: 1085
# Unique values in 2020: 1085
# Unique values in 2019: 1085
# Unique values in 2018: 1085
# Unique values in 2017: 1085
# Unique values in 2016: 1085
# Unique values in 2015: 1085
# Unique values in 2014: 1085
# Unique values in 2013: 1085
# Unique values in 2012: 1084
# Unique values in 2011: 1085
# Unique values in 2010: 1084
# Unique values in 2009: 1085
# Unique values in 2008: 1085
# Unique values in 2007: 1085
# Unique values in 2006: 1085
# Unique values in 2005: 1085
# Unique values in 2004: 1085
# Unique values in 2003: 1085
# Unique values in 2002: 1085
# Unique values in 2001: 1085

# %% [markdown]
# ## Extraction of top 10 countries with respect to total population (for the latest year available)

# %%
# Rename columns to remove non-breaking spaces
df.columns = df.columns.str.replace('\xa0', ' ')

# Now proceed with the original code
total_population_data = df[df['Series Code'] == 'SP.POP.TOTL']
total_population_sorted = total_population_data.sort_values(by="2022", ascending=False)
total_top_ten_countries = total_population_sorted.head(10)

print("Top ten countries of total population \n")
print(total_top_ten_countries[['Country Code']])
# Out:
# Top ten countries of total population
#
#     Country Code
# 89           IND
# 41           CHN
# 206          USA
# 90           IDN
# 149          PAK
# 144          NGA
# 26           BRA
# 15           BGD
# 161          RUS
# 127          MEX

# %% [markdown]
# ## Bar Plot for Top Ten Countries by Total Population

# %%
plt.figure(figsize=(10, 6))
plt.bar(total_top_ten_countries['Country Code'], total_top_ten_countries['2022'], color='skyblue')
plt.title('Top 10 Countries by Total Population in 2022')
plt.xlabel('Country')
plt.ylabel('Total Population')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Extraction of Top 10 Countries with Respect to Total Population

# %%
import pandas as pd

# Step 1: Load the CSV file into a DataFrame
df = pd.read_csv('worldpopulationdata.csv')

# Step 2: Filter and Sort the Data
total_population_data = df[df['Series Code'] == 'SP.POP.TOTL']
total_population_sorted = total_population_data.sort_values(by="2022", ascending=False)
total_top_ten_countries = total_population_sorted.head(10)

# Step 3: Print the Top Ten Countries by Population in 2022 and 2016
print("Top ten countries by total population in 2022 and 2016:")
print(total_top_ten_countries[['Country Code', 'Country Name', '2022', '2016']])
# Out:
# Top ten countries by total population in 2022 and 2016:
#     Country Code        Country Name          2022          2016
# 89           IND               India  1.417173e+09  1.338636e+09
# 41           CHN               China  1.412175e+09  1.387790e+09
# 206          USA       United States  3.332876e+08  3.230718e+08
# 90           IDN           Indonesia  2.755013e+08  2.618502e+08
# 149          PAK            Pakistan  2.358249e+08  2.135248e+08
# 144          NGA             Nigeria  2.185412e+08  1.886669e+08
# 26           BRA              Brazil  2.153135e+08  2.068596e+08
# 15           BGD          Bangladesh  1.711864e+08  1.597846e+08
# 161          RUS  Russian Federation  1.435557e+08  1.443424e+08
# 127          MEX              Mexico  1.275041e+08  1.215192e+08

# %% [markdown]
# ## Bar Plot for Top Ten Countries by Total Population

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file into a DataFrame
df = pd.read_csv('worldpopulationdata.csv')

# Filter the data for total population
total_population_data = df[df['Series Code'] == 'SP.POP.TOTL']

# Sort data based on the total population for 2022
total_population_sorted = total_population_data.sort_values(by="2022", ascending=False)

# Get the top ten countries with the highest total population for 2022
total_top_ten_countries = total_population_sorted.head(10)

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(total_top_ten_countries['Country Name'], total_top_ten_countries['2022'], color='skyblue')
plt.title('Top 10 Countries by Total Population in 2022')
plt.xlabel('Country')
plt.ylabel('Total Population')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Bottom Ten Countries of Total Population in 2022 and 2016

# %%
print("Bottom ten countries by total population in 2022 and 2016:")
print(total_bottom_ten_countries[['Country Code', 'Country Name', '2022', '2016']])
# Out:
# Bottom ten countries by total population in 2022 and 2016:
#     Country Code              Country Name     2022     2016
# 124          MHL          Marshall Islands  41569.0  48329.0
# 114          LIE             Liechtenstein  39327.0  37609.0
# 130          MCO                    Monaco  36469.0  37071.0
# 164          SMR                San Marino  33660.0  33834.0
# 75           GIB                 Gibraltar  32649.0  32565.0
# 183          MAF  St. Martin (French part)  31791.0  34811.0
# 27           VGB    British Virgin Islands  31305.0  29739.0
# 150          PLW                     Palau  18055.0  17816.0
# 137          NRU                     Nauru  12668.0  11437.0
# 201          TUV                    Tuvalu  11312.0  10852.0

# %% [markdown]
# ## Extraction of Top 10 Countries with Respect to Total Population

# %%
# Step 1: Filter and Sort the Data
total_population_data = df[df['Series Code'] == 'SP.POP.TOTL']
total_population_sorted = total_population_data.sort_values(by="2022", ascending=True)
total_bottom_ten_countries = total_population_sorted.head(10)

# Step 2: Print the bottom Ten Countries by Population in 2022 and 2016
print("bottom ten countries by total population in 2022 and 2016:")
print(total_bottom_ten_countries[['Country Code', 'Country Name', '2022', '2016']])
# Out:
# bottom ten countries by total population in 2022 and 2016:
#     Country Code              Country Name     2022     2016
# 201          TUV                    Tuvalu  11312.0  10852.0
# 137          NRU                     Nauru  12668.0  11437.0
# 150          PLW                     Palau  18055.0  17816.0
# 27           VGB    British Virgin Islands  31305.0  29739.0
# 183          MAF  St. Martin (French part)  31791.0  34811.0
# 75           GIB                 Gibraltar  32649.0  32565.0
# 164          SMR                San Marino  33660.0  33834.0
# 130          MCO                    Monaco  36469.0  37071.0
# 114          LIE             Liechtenstein  39327.0  37609.0
# 124          MHL          Marshall Islands  41569.0  48329.0

# %% [markdown]
# ## Bar Plot for bottom Ten Countries by Total Population

# %%
# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(total_bottom_ten_countries['Country Name'], total_bottom_ten_countries['2022'], color='skyblue')
plt.title('bottom 10 Countries by Total Population in 2022')
plt.xlabel('Country')
plt.ylabel('Total Population')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Extraction of top 10 countries with highest male population

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('worldpopulationdata.csv')

# Clean up column names by removing extra spaces
df.columns = df.columns.str.replace('\xa0', ' ').str.strip()

# Filter data for male population
male_population_data = df[df['Series Code'] == 'SP.POP.TOTL.MA.IN']

# Sort data based on the male population for 2022
male_population_sorted = male_population_data.sort_values(by="2022", ascending=False)

# Get the top 10 countries with the highest male population for 2022
male_top_ten_countries = male_population_sorted.head(10)

print("Top ten countries of male population:")
print(male_top_ten_countries[['Country Code']])
# Out:
# Top ten countries of male population:
#     Country Code
# 523          IND
# 475          CHN
# 640          USA
# 524          IDN
# 583          PAK
# 578          NGA
# 460          BRA
# 449          BGD
# 595          RUS
# 561          MEX

# %%
# Filter data for female population
female_population_data = df[df['Series Code'] == 'SP.POP.TOTL.FE.IN']

# Sort data based on the female population for 2022
female_population_sorted = female_population_data.sort_values(by="2022", ascending=False)

# Get the top 10 countries with the highest female population for 2022
female_top_ten_countries = female_population_sorted.head(10)

print("Top ten countries of female population:")
print(female_top_ten_countries[['Country Code']])
# Out:
# Top ten countries of female population:
#     Country Code
# 258          CHN
# 306          IND
# 423          USA
# 307          IDN
# 366          PAK
# 243          BRA
# 361          NGA
# 232          BGD
# 378          RUS
# 344          MEX

# %% [markdown]
# ## Top 10 countries with highest male and female population in 2022

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create the bar plot
plt.figure(figsize=(15, 6))

# Plot for male population
plt.subplot(2, 2, 1)
sns.barplot(x="2022", y="Country Code", data=male_top_ten_countries, palette="viridis")

plt.title("Top ten countries of male population (2022)", fontsize=10)
plt.xlabel("Male Population", fontsize=10)
plt.ylabel("Country", fontsize=10)

# Plot for female population
plt.subplot(2, 2, 2)
sns.barplot(x="2022", y="Country Code", data=female_top_ten_countries, palette="viridis")

plt.title("Top ten countries of female population (2022)", fontsize=10)
plt.xlabel("Female Population", fontsize=10)
plt.ylabel("Country", fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\drp37\AppData\Local\Temp\ipykernel_17200\1943853277.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2022", y="Country Code", data=male_top_ten_countries, palette="viridis")
# C:\Users\drp37\AppData\Local\Temp\ipykernel_17200\1943853277.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2022", y="Country Code", data=female_top_ten_countries, palette="viridis")

# %% [markdown]
# # Stacked Bar Plot

# %% [markdown]
# ## Top 10 countries with male and female population

# %%
# Merge male and female population data on 'Country Code'
merge_data = pd.merge(male_population_data, female_population_data, on="Country Code", suffixes=("_male", "_female"))

# %%
# Calculate the total population for each country (male + female)
merge_data["Total population"] = merge_data["2022_male"] + merge_data["2022_female"]

# %%
# Display the merged data
merge_data.head()
# Out:
#    Series Name_male   Series Code_male Country Name_male Country Code  \
# 0  Population, male  SP.POP.TOTL.MA.IN       Afghanistan          AFG
# 1  Population, male  SP.POP.TOTL.MA.IN           Albania          ALB
# 2  Population, male  SP.POP.TOTL.MA.IN           Algeria          DZA
# 3  Population, male  SP.POP.TOTL.MA.IN    American Samoa          ASM
# 4  Population, male  SP.POP.TOTL.MA.IN           Andorra          AND
#
#     2022_male   2021_male   2020_male   2019_male   2018_male   2017_male  \
# 0  20766442.0  20254878.0  19692301.0  19090409.0  18549862.0  18028696.0
# 1   1384548.0   1404454.0   1419264.0   1428828.0   1435881.0   1440219.0
# 2  22862237.0  22497244.0  22132899.0  21756903.0  21362603.0  20961313.0
# 3     21873.0     22289.0     22921.0     23535.0     24134.0     24701.0
# 4     40786.0     40361.0     39615.0     38842.0     38071.0     37380.0
#
#    ...  2009_female  2008_female  2007_female  2006_female  2005_female  \
# ...

# %%
# Sort data based on total population in descending order
sorted_data = merge_data.sort_values(by="Total population", ascending=False)

# %% [markdown]
# ## Select the top 10 countries with the highest total population

# %%
top_10_countries = sorted_data.head(10)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming top_10_countries is already defined with relevant data

plt.figure(figsize=(12, 6))

# Plot for female population
sns.barplot(x="Country Code", y="2022_female", data=top_10_countries, color="lightpink", label="Female Population")

# Plot for male population (stacked on top of female population)
sns.barplot(x="Country Code", y="2022_male", data=top_10_countries, color="skyblue", label="Male Population", alpha=0.7)

plt.title("Top 10 Countries by Male and Female Population in 2022")
plt.xlabel("Country Code")
plt.ylabel("Population")
plt.xticks(rotation=45, ha="right")
plt.legend()

plt.show()

# %% [markdown]
# ## Bottom 10 countries with male and female population

# %%
#select the bottom 10 countries with the lowest total population
bottom_10_countries = sorted_data.tail(10)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Plot for female population
sns.barplot(x="Country Code", y="2022_female", data=bottom_10_countries, color="lightpink", label="Female Population")

# Plot for male population (stacked on top of female population)
sns.barplot(x="Country Code", y="2022_male", data=bottom_10_countries, color="skyblue", label="Male Population", alpha=0.7)

plt.title("bottom 10 Countries by Male and Female Population in 2022")
plt.xlabel("Country Code")
plt.ylabel("Population")
plt.xticks(rotation=45, ha="right")
plt.legend()

plt.show()
